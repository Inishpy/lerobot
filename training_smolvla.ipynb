# %% [markdown]
# # 🤗 x 🦾: Training SmolVLA with LeRobot Notebook
#
# Welcome to the **LeRobot SmolVLA training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `SmolVLA` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `SmolVLA` policy for 20,000 steps typically takes **about 5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer!
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/condacolab.py:27
#      26 try:
# ---> 27     import google.colab
#      28 except ImportError:
#
# ModuleNotFoundError: No module named 'google.colab'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().system('pip install -q condacolab')
# ----> 2 import condacolab
#       3 condacolab.install()
#
# File ~/.local/lib/python3.10/site-packages/condacolab.py:29
#      27     import google.colab
#      28 except ImportError:
# ---> 29     raise RuntimeError("This module must ONLY run as part of a Colab notebook!")
#      32 __version__ = "0.1.9"
#      33 __author__ = "Jaime Rodríguez-Guerra <jaimergp@users.noreply.github.com>"
#
# RuntimeError: This module must ONLY run as part of a Colab notebook!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# Out:
# fatal: destination path 'lerobot' already exists and is not an empty directory.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/lunet/coimd/.conda/envs/lerobot
#
#   added / updated specs:
#     - ffmpeg=7.1.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     dbus-1.16.2                |       h3c4dab8_0         428 KB  conda-forge
#     ffmpeg-7.1.1               | gpl_h127656b_906         9.9 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     gettext-0.25.1             |       h5888daf_0         525 KB  conda-forge
#     gettext-tools-0.25.1       |       h5888daf_0         3.5 MB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     graphite2-1.3.14           |       h5888daf_0          96 KB  conda-forge
#     harfbuzz-11.2.1            |       h3beb420_0         1.7 MB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     level-zero-1.23.1          |       h84d6215_0         591 KB  conda-forge
#     libabseil-20250127.1       | cxx17_hbbce691_0         1.3 MB  conda-forge
#     libasprintf-0.25.1         |       h8e693c7_0          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h8e693c7_0          34 KB  conda-forge
#     libass-0.17.3              |       h52826cd_2         149 KB  conda-forge
#     libcap-2.75                |       h39aace5_0         118 KB  conda-forge
#     libdeflate-1.24            |       h86f0d12_0          71 KB  conda-forge
#     libdrm-2.4.125             |       hb9d3cd8_0         240 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libgcrypt-lib-1.11.1       |       hb9d3cd8_0         577 KB  conda-forge
#     libgettextpo-0.25.1        |       h5888daf_0         174 KB  conda-forge
#     libgettextpo-devel-0.25.1  |       h5888daf_0          36 KB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libglib-2.84.2             |       h3618099_0         3.8 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libgpg-error-1.55          |       h3f2d84a_0         305 KB  conda-forge
#     libhwloc-2.11.2            |default_h3d81e11_1002         2.3 MB  conda-forge
#     libiconv-1.18              |       h4ce23a2_1         696 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     libogg-1.3.5               |       hd0c01bc_1         213 KB  conda-forge
#     libopenvino-2025.0.0       |       hdc3f47d_3         5.4 MB  conda-forge
#     libopenvino-auto-batch-plugin-2025.0.0|       h4d9b6c2_3         109 KB  conda-forge
#     libopenvino-auto-plugin-2025.0.0|       h4d9b6c2_3         233 KB  conda-forge
#     libopenvino-hetero-plugin-2025.0.0|       h981d57b_3         191 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2025.0.0|       hdc3f47d_3        11.8 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2025.0.0|       hdc3f47d_3         9.7 MB  conda-forge
#     libopenvino-intel-npu-plugin-2025.0.0|       hdc3f47d_3         1.0 MB  conda-forge
#     libopenvino-ir-frontend-2025.0.0|       h981d57b_3         201 KB  conda-forge
#     libopenvino-onnx-frontend-2025.0.0|       h0e684df_3         1.6 MB  conda-forge
#     libopenvino-paddle-frontend-2025.0.0|       h0e684df_3         674 KB  conda-forge
#     libopenvino-pytorch-frontend-2025.0.0|       h5888daf_3         1.1 MB  conda-forge
#     libopenvino-tensorflow-frontend-2025.0.0|       h684f15b_3         1.3 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2025.0.0|       h5888daf_3         477 KB  conda-forge
#     libopus-1.5.2              |       hd0c01bc_0         305 KB  conda-forge
#     libpciaccess-0.18          |       hb9d3cd8_0          28 KB  conda-forge
#     libpng-1.6.50              |       h943b412_0         282 KB  conda-forge
#     libprotobuf-5.29.3         |       h501fc15_1         3.2 MB  conda-forge
#     librsvg-2.58.4             |       he92a37e_3         6.2 MB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libsystemd0-257.7          |       h4e0b6ca_0         477 KB  conda-forge
#     libtiff-4.7.0              |       hf01ce69_5         420 KB  conda-forge
#     libudev1-257.7             |       hbe16f8c_0         140 KB  conda-forge
#     libunwind-1.8.2            |       h1441ba7_0          74 KB  conda-forge
#     liburing-2.11              |       h84d6215_0         123 KB  conda-forge
#     libusb-1.0.29              |       h73b1eb8_0          87 KB  conda-forge
#     libva-2.22.0               |       h4f16b4b_2         212 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     libwebp-base-1.6.0         |       hd42ef1d_0         419 KB  conda-forge
#     libxkbcommon-1.10.0        |       h65c71a3_0         691 KB  conda-forge
#     libxml2-2.13.8             |       h4bc477f_0         675 KB  conda-forge
#     lz4-c-1.10.0               |       h5888daf_1         163 KB  conda-forge
#     mpg123-1.32.9              |       hc50e24c_0         480 KB  conda-forge
#     ocl-icd-2.3.3              |       hb9d3cd8_0         104 KB  conda-forge
#     opencl-headers-2025.06.13  |       h5888daf_0          54 KB  conda-forge
#     openh264-2.6.0             |       hc22cd8d_0         714 KB  conda-forge
#     pango-1.56.4               |       hadf4263_0         445 KB  conda-forge
#     pcre2-10.45                |       hc749103_0         1.1 MB  conda-forge
#     pixman-0.46.2              |       h29eaf8c_0         393 KB  conda-forge
#     pugixml-1.15               |       h3f63f65_0         116 KB  conda-forge
#     pulseaudio-client-17.0     |       hac146a9_1         746 KB  conda-forge
#     sdl2-2.32.54               |       h3f2d84a_0         573 KB  conda-forge
#     sdl3-3.2.18                |       h68140b3_0         1.8 MB  conda-forge
#     snappy-1.2.1               |       h8bd8927_1          42 KB  conda-forge
#     svt-av1-3.0.2              |       h5888daf_0         2.6 MB  conda-forge
#     tbb-2022.1.0               |       h4ce085d_0         175 KB  conda-forge
#     wayland-1.24.0             |       h3e06ad9_0         323 KB  conda-forge
#     wayland-protocols-1.45     |       hd8ed1ab_0         135 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xkeyboard-config-2.45      |       hb9d3cd8_0         383 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libxcursor-1.2.3      |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.1       |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxscrnsaver-1.2.4   |       hb9d3cd8_0          14 KB  conda-forge
#     zstd-1.5.7                 |       hb8e6e7a_2         554 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       113.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.14-hb9d3cd8_0
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   dbus               conda-forge/linux-64::dbus-1.16.2-h3c4dab8_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.1.1-gpl_h127656b_906
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   gettext            conda-forge/linux-64::gettext-0.25.1-h5888daf_0
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.25.1-h5888daf_0
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.14-h5888daf_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-11.2.1-h3beb420_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   level-zero         conda-forge/linux-64::level-zero-1.23.1-h84d6215_0
#   libabseil          conda-forge/linux-64::libabseil-20250127.1-cxx17_hbbce691_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.25.1-h8e693c7_0
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.25.1-h8e693c7_0
#   libass             conda-forge/linux-64::libass-0.17.3-h52826cd_2
#   libcap             conda-forge/linux-64::libcap-2.75-h39aace5_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.24-h86f0d12_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.125-hb9d3cd8_0
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.1-hb9d3cd8_0
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.25.1-h5888daf_0
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.25.1-h5888daf_0
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.84.2-h3618099_0
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.55-h3f2d84a_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.11.2-default_h3d81e11_1002
#   libiconv           conda-forge/linux-64::libiconv-1.18-h4ce23a2_1
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.0-hb9d3cd8_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-hd0c01bc_1
#   libopenvino        conda-forge/linux-64::libopenvino-2025.0.0-hdc3f47d_3
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2025.0.0-h4d9b6c2_3
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2025.0.0-h4d9b6c2_3
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2025.0.0-h981d57b_3
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2025.0.0-hdc3f47d_3
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2025.0.0-hdc3f47d_3
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2025.0.0-hdc3f47d_3
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2025.0.0-h981d57b_3
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2025.0.0-h0e684df_3
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2025.0.0-h0e684df_3
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2025.0.0-h5888daf_3
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2025.0.0-h684f15b_3
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2025.0.0-h5888daf_3
#   libopus            conda-forge/linux-64::libopus-1.5.2-hd0c01bc_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.50-h943b412_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-5.29.3-h501fc15_1
#   librsvg            conda-forge/linux-64::librsvg-2.58.4-he92a37e_3
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsystemd0        conda-forge/linux-64::libsystemd0-257.7-h4e0b6ca_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hf01ce69_5
#   libudev1           conda-forge/linux-64::libudev1-257.7-hbe16f8c_0
#   libunwind          conda-forge/linux-64::libunwind-1.8.2-h1441ba7_0
#   liburing           conda-forge/linux-64::liburing-2.11-h84d6215_0
#   libusb             conda-forge/linux-64::libusb-1.0.29-h73b1eb8_0
#   libva              conda-forge/linux-64::libva-2.22.0-h4f16b4b_2
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.10.0-h65c71a3_0
#   libxml2            conda-forge/linux-64::libxml2-2.13.8-h4bc477f_0
#   lz4-c              conda-forge/linux-64::lz4-c-1.10.0-h5888daf_1
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.3-hb9d3cd8_0
#   opencl-headers     conda-forge/linux-64::opencl-headers-2025.06.13-h5888daf_0
#   openh264           conda-forge/linux-64::openh264-2.6.0-hc22cd8d_0
#   pango              conda-forge/linux-64::pango-1.56.4-hadf4263_0
#   pcre2              conda-forge/linux-64::pcre2-10.45-hc749103_0
#   pixman             conda-forge/linux-64::pixman-0.46.2-h29eaf8c_0
#   pugixml            conda-forge/linux-64::pugixml-1.15-h3f63f65_0
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-hac146a9_1
#   sdl2               conda-forge/linux-64::sdl2-2.32.54-h3f2d84a_0
#   sdl3               conda-forge/linux-64::sdl3-3.2.18-h68140b3_0
#   snappy             conda-forge/linux-64::snappy-1.2.1-h8bd8927_1
#   svt-av1            conda-forge/linux-64::svt-av1-3.0.2-h5888daf_0
#   tbb                conda-forge/linux-64::tbb-2022.1.0-h4ce085d_0
#   wayland            conda-forge/linux-64::wayland-1.24.0-h3e06ad9_0
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.45-hd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.45-hb9d3cd8_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libxcursor    conda-forge/linux-64::xorg-libxcursor-1.2.3-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.1-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxscrnsaver conda-forge/linux-64::xorg-libxscrnsaver-1.2.4-hb9d3cd8_0
#   zstd               conda-forge/linux-64::zstd-1.5.7-hb8e6e7a_2
#
#
# Proceed ([y]/n)?
# CondaSystemExit:
# Operation aborted.  Exiting.
#
# ^C
# Obtaining file:///home/lunet/coimd/leRobot/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting datasets<=3.6.0,>=2.19.0 (from lerobot==0.1.0)
#   Using cached datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting diffusers>=0.27.2 (from lerobot==0.1.0)
#   Using cached diffusers-0.34.0-py3-none-any.whl.metadata (20 kB)
# Collecting huggingface-hub>=0.27.1 (from huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0)
#   Using cached huggingface_hub-0.33.4-py3-none-any.whl.metadata (14 kB)
# Collecting cmake>=3.29.0.1 (from lerobot==0.1.0)
#   Using cached cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Collecting einops>=0.8.0 (from lerobot==0.1.0)
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting opencv-python-headless>=4.9.0 (from lerobot==0.1.0)
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting av>=14.2.0 (from lerobot==0.1.0)
#   Using cached av-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting torch>=2.2.1 (from lerobot==0.1.0)
#   Using cached torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchcodec>=0.2.1 (from lerobot==0.1.0)
#   Using cached torchcodec-0.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting torchvision>=0.21.0 (from lerobot==0.1.0)
#   Using cached torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting jsonlines>=4.0.0 (from lerobot==0.1.0)
#   Using cached jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging>=24.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (25.0)
# Collecting pynput>=1.7.7 (from lerobot==0.1.0)
#   Using cached pynput-1.8.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting pyserial>=3.5 (from lerobot==0.1.0)
#   Using cached pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting wandb>=0.16.3 (from lerobot==0.1.0)
#   Using cached wandb-0.21.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting draccus==0.10.0 (from lerobot==0.1.0)
#   Using cached draccus-0.10.0-py3-none-any.whl.metadata (24 kB)
# Collecting gymnasium<1.0.0,>=0.29.1 (from lerobot==0.1.0)
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting rerun-sdk<0.23.0,>=0.21.0 (from lerobot==0.1.0)
#   Using cached rerun_sdk-0.22.1-cp38-abi3-manylinux_2_31_x86_64.whl.metadata (4.4 kB)
# Collecting deepdiff<9.0.0,>=7.0.1 (from lerobot==0.1.0)
#   Using cached deepdiff-8.5.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting flask<4.0.0,>=3.0.3 (from lerobot==0.1.0)
#   Using cached flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting imageio<3.0.0,>=2.34.0 (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0)
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting termcolor<4.0.0,>=2.4.0 (from lerobot==0.1.0)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting mergedeep~=1.3 (from draccus==0.10.0->lerobot==0.1.0)
#   Using cached mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyyaml~=6.0 (from draccus==0.10.0->lerobot==0.1.0)
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pyyaml-include~=1.4 (from draccus==0.10.0->lerobot==0.1.0)
#   Using cached pyyaml_include-1.4.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting toml~=0.10 (from draccus==0.10.0->lerobot==0.1.0)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect~=0.9.0 (from draccus==0.10.0->lerobot==0.1.0)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting filelock (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy>=1.17 (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pyarrow>=15.0.0 (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached pyarrow-21.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/lunet/coimd/.local/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.2.3)
# Collecting requests>=2.32.2 (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm>=4.66.3 (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff<9.0.0,>=7.0.1->lerobot==0.1.0)
#   Using cached orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting blinker>=1.9.0 (from flask<4.0.0,>=3.0.3->lerobot==0.1.0)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from flask<4.0.0,>=3.0.3->lerobot==0.1.0)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting itsdangerous>=2.2.0 (from flask<4.0.0,>=3.0.3->lerobot==0.1.0)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from flask<4.0.0,>=3.0.3->lerobot==0.1.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (3.1.3)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached aiohttp-3.12.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium<1.0.0,>=0.29.1->lerobot==0.1.0)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from gymnasium<1.0.0,>=0.29.1->lerobot==0.1.0) (4.14.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.0.0,>=0.29.1->lerobot==0.1.0)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting pillow>=8.3.2 (from imageio<3.0.0,>=2.34.0->imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0)
#   Using cached pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting imageio-ffmpeg (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0)
#   Using cached imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: psutil in /home/lunet/coimd/.local/lib/python3.10/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0) (7.0.0)
# Collecting attrs>=23.1.0 (from rerun-sdk<0.23.0,>=0.21.0->lerobot==0.1.0)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.1.0)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Collecting idna>=2.0 (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib_metadata in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from diffusers>=0.27.2->lerobot==0.1.0) (8.7.0)
# Collecting regex!=2019.12.17 (from diffusers>=0.27.2->lerobot==0.1.0)
#   Using cached regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting safetensors>=0.3.1 (from diffusers>=0.27.2->lerobot==0.1.0)
#   Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.27.1->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0)
#   Using cached hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting InquirerPy==0.3.4 (from huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0)
#   Using cached InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting hf-transfer>=0.1.4 (from huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0)
#   Using cached hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0)
#   Using cached pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (3.0.51)
# Requirement already satisfied: wcwidth in /home/lunet/coimd/.local/lib/python3.10/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (0.2.13)
# Requirement already satisfied: six in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.17.0)
# Collecting evdev>=1.3 (from pynput>=1.7.7->lerobot==0.1.0)
#   Using cached evdev-1.9.2-cp310-cp310-linux_x86_64.whl
# Collecting python-xlib>=0.17 (from pynput>=1.7.7->lerobot==0.1.0)
#   Using cached python_xlib-0.33-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting sympy>=1.13.3 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch>=2.2.1->lerobot==0.1.0)
#   Using cached triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from triton==3.3.1->torch>=2.2.1->lerobot==0.1.0) (80.9.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.2.1->lerobot==0.1.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb>=0.16.3->lerobot==0.1.0)
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /home/lunet/coimd/.local/lib/python3.10/site-packages (from wandb>=0.16.3->lerobot==0.1.0) (4.3.8)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb>=0.16.3->lerobot==0.1.0)
#   Using cached protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wandb>=0.16.3->lerobot==0.1.0)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb>=0.16.3->lerobot==0.1.0)
#   Using cached sentry_sdk-2.33.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0)
#   Using cached pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: zipp>=3.20 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from importlib_metadata->diffusers>=0.27.2->lerobot==0.1.0) (3.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2025.2)
# Using cached draccus-0.10.0-py3-none-any.whl (71 kB)
# Using cached datasets-3.6.0-py3-none-any.whl (491 kB)
# Using cached deepdiff-8.5.0-py3-none-any.whl (85 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached flask-3.1.1-py3-none-any.whl (103 kB)
# Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Using cached multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Using cached orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Using cached pyyaml_include-1.4.1-py3-none-any.whl (19 kB)
# Using cached rerun_sdk-0.22.1-cp38-abi3-manylinux_2_31_x86_64.whl (51.4 MB)
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached aiohttp-3.12.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
# Using cached yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached av-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.2 MB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.9 MB)
# Using cached diffusers-0.34.0-py3-none-any.whl (3.8 MB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Using cached frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (222 kB)
# Using cached huggingface_hub-0.33.4-py3-none-any.whl (515 kB)
# Using cached hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached InquirerPy-0.3.4-py3-none-any.whl (67 kB)
# Using cached pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Using cached hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Using cached opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
# Using cached pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
# Using cached propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (198 kB)
# Using cached pyarrow-21.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.7 MB)
# Using cached pynput-1.8.1-py2.py3-none-any.whl (91 kB)
# Using cached pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Using cached python_xlib-0.33-py2.py3-none-any.whl (182 kB)
# Using cached regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.7.14-py3-none-any.whl (162 kB)
# Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 39.9 MB/s eta 0:00:0000:0100:01
# Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 55.5 MB/s eta 0:00:0000:0100:01
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading torchcodec-0.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.1 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 37.0 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached wandb-0.21.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
# Using cached protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sentry_sdk-2.33.0-py2.py3-none-any.whl (356 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.0 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.1.0-0.editable-py3-none-any.whl size=16707 sha256=dc14ea6abdd34faf480449855342cba12958f647e56c47486174ffb724ac0773
#   Stored in directory: /tmp/pip-ephem-wheel-cache-atjujk2v/wheels/47/2d/a3/588b3be80c5635e2fa3e690e2af825d351b938e933b15a7669
# Successfully built lerobot
# Installing collected packages: pytz, pyserial, nvidia-cusparselt-cu12, mpmath, farama-notifications, xxhash, urllib3, typing-inspection, triton, tqdm, torchcodec, toml, termcolor, sympy, smmap, safetensors, regex, pyyaml, python-xlib, pydantic-core, pyarrow, protobuf, propcache, pillow, pfzy, orderly-set, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mypy-extensions, multidict, mergedeep, jinja2, itsdangerous, imageio-ffmpeg, idna, hf-xet, hf-transfer, fsspec, frozenlist, filelock, evdev, einops, dill, cmake, cloudpickle, click, charset_normalizer, certifi, blinker, av, attrs, async-timeout, annotated-types, aiohappyeyeballs, yarl, typing-inspect, sentry-sdk, rerun-sdk, requests, pyyaml-include, pynput, pydantic, opencv-python-headless, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, jsonlines, InquirerPy, imageio, gymnasium, gitdb, flask, deepdiff, aiosignal, nvidia-cusolver-cu12, huggingface-hub, gitpython, draccus, aiohttp, wandb, torch, diffusers, torchvision, datasets, lerobot
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95/95 [lerobot][datasets]torchvision]hub]cu12]s]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch-tb-profiler 0.4.3 requires tensorboard!=2.1.0,>=1.15, which is not installed.
# Successfully installed InquirerPy-0.3.4 aiohappyeyeballs-2.6.1 aiohttp-3.12.14 aiosignal-1.4.0 annotated-types-0.7.0 async-timeout-5.0.1 attrs-25.3.0 av-15.0.0 blinker-1.9.0 certifi-2025.7.14 charset_normalizer-3.4.2 click-8.2.1 cloudpickle-3.1.1 cmake-4.0.3 datasets-3.6.0 deepdiff-8.5.0 diffusers-0.34.0 dill-0.3.8 draccus-0.10.0 einops-0.8.1 evdev-1.9.2 farama-notifications-0.0.4 filelock-3.18.0 flask-3.1.1 frozenlist-1.7.0 fsspec-2025.3.0 gitdb-4.0.12 gitpython-3.1.44 gymnasium-0.29.1 hf-transfer-0.1.9 hf-xet-1.1.5 huggingface-hub-0.33.4 idna-3.10 imageio-2.37.0 imageio-ffmpeg-0.6.0 itsdangerous-2.2.0 jinja2-3.1.6 jsonlines-4.0.0 lerobot-0.1.0 mergedeep-1.3.4 mpmath-1.3.0 multidict-6.6.3 multiprocess-0.70.16 mypy-extensions-1.1.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 opencv-python-headless-4.12.0.88 orderly-set-5.5.0 pfzy-0.3.4 pillow-11.3.0 propcache-0.3.2 protobuf-6.31.1 pyarrow-21.0.0 pydantic-2.11.7 pydantic-core-2.33.2 pynput-1.8.1 pyserial-3.5 python-xlib-0.33 pytz-2025.2 pyyaml-6.0.2 pyyaml-include-1.4.1 regex-2024.11.6 requests-2.32.4 rerun-sdk-0.22.1 safetensors-0.5.3 sentry-sdk-2.33.0 smmap-5.0.2 sympy-1.14.0 termcolor-3.1.0 toml-0.10.2 torch-2.7.1 torchcodec-0.4.0 torchvision-0.22.1 tqdm-4.67.1 triton-3.3.1 typing-inspect-0.9.0 typing-inspection-0.4.1 urllib3-2.5.0 wandb-0.21.0 xxhash-3.5.0 yarl-1.20.1

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: http://localhost:8080/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# Aborted!
# ^C

# %% [markdown]
# ## Install SmolVLA dependencies

# %%
# !cd lerobot && pip install -e ".[smolvla]"
# Out:
# Obtaining file:///home/lunet/coimd/leRobot/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<=3.6.0,>=2.19.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (3.6.0)
# Requirement already satisfied: diffusers>=0.27.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.34.0)
# Requirement already satisfied: huggingface-hub>=0.27.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (0.33.4)
# Requirement already satisfied: cmake>=3.29.0.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (4.0.3)
# Requirement already satisfied: einops>=0.8.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.8.1)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (4.12.0.88)
# Requirement already satisfied: av>=14.2.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (15.0.0)
# Requirement already satisfied: torch>=2.2.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (2.7.1)
# Requirement already satisfied: torchcodec>=0.2.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.4.0)
# Requirement already satisfied: torchvision>=0.21.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.22.1)
# Requirement already satisfied: jsonlines>=4.0.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (4.0.0)
# Requirement already satisfied: packaging>=24.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (25.0)
# Requirement already satisfied: pynput>=1.7.7 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (1.8.1)
# Requirement already satisfied: pyserial>=3.5 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (3.5)
# Requirement already satisfied: wandb>=0.16.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.21.0)
# Requirement already satisfied: draccus==0.10.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.10.0)
# Requirement already satisfied: gymnasium<1.0.0,>=0.29.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.29.1)
# Requirement already satisfied: rerun-sdk<0.23.0,>=0.21.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.22.1)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (8.5.0)
# Requirement already satisfied: flask<4.0.0,>=3.0.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (3.1.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0) (2.37.0)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (3.1.0)
# Collecting num2words>=0.5.14 (from lerobot==0.1.0)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting accelerate>=1.7.0 (from lerobot==0.1.0)
#   Downloading accelerate-1.9.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from lerobot==0.1.0) (0.5.3)
# Requirement already satisfied: mergedeep~=1.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from draccus==0.10.0->lerobot==0.1.0) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from draccus==0.10.0->lerobot==0.1.0) (6.0.2)
# Requirement already satisfied: pyyaml-include~=1.4 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from draccus==0.10.0->lerobot==0.1.0) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from draccus==0.10.0->lerobot==0.1.0) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from draccus==0.10.0->lerobot==0.1.0) (0.9.0)
# Requirement already satisfied: filelock in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.2.6)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /home/lunet/coimd/.local/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (4.67.1)
# Requirement already satisfied: xxhash in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2025.3.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.1.0) (5.5.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from flask<4.0.0,>=3.0.3->lerobot==0.1.0) (3.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (3.12.14)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from gymnasium<1.0.0,>=0.29.1->lerobot==0.1.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from gymnasium<1.0.0,>=0.29.1->lerobot==0.1.0) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from gymnasium<1.0.0,>=0.29.1->lerobot==0.1.0) (0.0.4)
# Requirement already satisfied: pillow>=8.3.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from imageio<3.0.0,>=2.34.0->imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0) (11.3.0)
# Requirement already satisfied: imageio-ffmpeg in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0) (0.6.0)
# Requirement already satisfied: psutil in /home/lunet/coimd/.local/lib/python3.10/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.1.0) (7.0.0)
# Requirement already satisfied: attrs>=23.1.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from rerun-sdk<0.23.0,>=0.21.0->lerobot==0.1.0) (25.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.1.0) (1.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (3.10)
# Requirement already satisfied: importlib_metadata in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from diffusers>=0.27.2->lerobot==0.1.0) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from diffusers>=0.27.2->lerobot==0.1.0) (2024.11.6)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from huggingface-hub>=0.27.1->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (1.1.5)
# Requirement already satisfied: InquirerPy==0.3.4 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (3.0.51)
# Requirement already satisfied: wcwidth in /home/lunet/coimd/.local/lib/python3.10/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1->lerobot==0.1.0) (0.2.13)
# Collecting docopt>=0.6.2 (from num2words>=0.5.14->lerobot==0.1.0)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.9.2)
# Requirement already satisfied: python-xlib>=0.17 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pynput>=1.7.7->lerobot==0.1.0) (0.33)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2025.7.14)
# Requirement already satisfied: sympy>=1.13.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from torch>=2.2.1->lerobot==0.1.0) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from triton==3.3.1->torch>=2.2.1->lerobot==0.1.0) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.2.1->lerobot==0.1.0) (1.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from wandb>=0.16.3->lerobot==0.1.0) (3.1.44)
# Requirement already satisfied: platformdirs in /home/lunet/coimd/.local/lib/python3.10/site-packages (from wandb>=0.16.3->lerobot==0.1.0) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from wandb>=0.16.3->lerobot==0.1.0) (6.31.1)
# Requirement already satisfied: pydantic<3 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.33.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.4.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (5.0.2)
# Requirement already satisfied: zipp>=3.20 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from importlib_metadata->diffusers>=0.27.2->lerobot==0.1.0) (3.23.0)
# Collecting transformers<4.52.0,>=4.50.3 (from lerobot==0.1.0)
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers<4.52.0,>=4.50.3->lerobot==0.1.0)
#   Using cached tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lunet/coimd/.conda/envs/lerobot/lib/python3.10/site-packages (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/lunet/coimd/.local/lib/python3.10/site-packages (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.1.0) (2025.2)
# Downloading accelerate-1.9.0-py3-none-any.whl (367 kB)
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 65.4 MB/s eta 0:00:00
# Using cached tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Building wheels for collected packages: lerobot, docopt
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.1.0-0.editable-py3-none-any.whl size=16707 sha256=b7be1a4d8d0615fd3b48d25fae500435a02697e96a1d9c350a1c6a2044ecf9f5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v3engmf_/wheels/47/2d/a3/588b3be80c5635e2fa3e690e2af825d351b938e933b15a7669
#   DEPRECATION: Building 'docopt' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'docopt'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13783 sha256=89b1e220d2dc41d95b952bcb5e27be9365e8dc01ceb38159524e43abe82d3d66
#   Stored in directory: /home/lunet/coimd/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built lerobot docopt
# Installing collected packages: docopt, num2words, tokenizers, transformers, accelerate, lerobot
#   Attempting uninstall: lerobot━━━╸━━━━━━━━━━━━━ 4/6 [accelerate]s]
#     Found existing installation: lerobot 0.1.090m━━━━━━━━━━━━━ 4/6 [accelerate]
#     Uninstalling lerobot-0.1.0:╸━━━━━━━━━━━━━ 4/6 [accelerate]
#       Successfully uninstalled lerobot-0.1.0━━━━━━━━━━━━━ 4/6 [accelerate]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [lerobot]m5/6 [lerobot]
# Successfully installed accelerate-1.9.0 docopt-0.6.2 lerobot-0.1.0 num2words-0.5.14 tokenizers-0.21.2 transformers-4.51.3

# %% [markdown]
# ## Start training SmolVLA with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--batch_size=64`: means the model processes 64 training samples in parallel before doing one gradient update. Reduce this number if you have a GPU with low memory.
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
# !cd lerobot && python lerobot/scripts/train.py \
  --policy.path=lerobot/smolvla_base \
  --dataset.repo_id=lerobot/libero_10_image \
  --batch_size=64 \
  --steps=20000 \
  --output_dir=outputs/train/my_smolvla \
  --job_name=my_smolvla_training \
  --policy.device=cuda \
  --wandb.enable=false

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !huggingface-cli login

# %%
# !huggingface-cli upload ${HF_USER}/my_smolvla \
  /content/lerobot/outputs/train/my_smolvla/checkpoints/last/pretrained_model
